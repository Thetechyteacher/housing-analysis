# %% [markdown]
# ## Cleaning and combining data for Total Dwellings Stock by Inner, Outer, City of London Regions and saving data for all years (2006-2022) together in one dataset:

# %%
import pandas as pd

# %%
total_dwellings_2006 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,H", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2006.insert(0, 'Year', '2006')
total_dwellings_2006
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2006            City of London                  5000
# 1   2006      Barking and Dagenham                 70000
# 2   2006                    Barnet                135000
# 3   2006                    Bexley                 93000
# 4   2006                     Brent                107000
# 5   2006                   Bromley                131000
# 6   2006                    Camden                 96000
# 7   2006                   Croydon                143000
# 8   2006                    Ealing                123000
# 9   2006                   Enfield                118000
# 10  2006                 Greenwich                101000
# 11  2006                   Hackney                 94000
# 12  2006    Hammersmith and Fulham                 79000
# 13  2006                  Haringey                 98000
# 14  2006                    Harrow                 83000
# ...

# %%
total_dwellings_2007 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,I", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2007.insert(0, 'Year', '2007')
total_dwellings_2007
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2007            City of London                  5000
# 1   2007      Barking and Dagenham                 70000
# 2   2007                    Barnet                135000
# 3   2007                    Bexley                 94000
# 4   2007                     Brent                108000
# 5   2007                   Bromley                132000
# 6   2007                    Camden                 97000
# 7   2007                   Croydon                144000
# 8   2007                    Ealing                124000
# 9   2007                   Enfield                119000
# 10  2007                 Greenwich                102000
# 11  2007                   Hackney                 95000
# 12  2007    Hammersmith and Fulham                 80000
# 13  2007                  Haringey                100000
# 14  2007                    Harrow                 84000
# ...

# %%
total_dwellings_2008 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,J", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2008.insert(0, 'Year', '2008')
total_dwellings_2008
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2008            City of London                  5000
# 1   2008      Barking and Dagenham                 71000
# 2   2008                    Barnet                137000
# 3   2008                    Bexley                 94000
# 4   2008                     Brent                109000
# 5   2008                   Bromley                133000
# 6   2008                    Camden                 98000
# 7   2008                   Croydon                145000
# 8   2008                    Ealing                126000
# 9   2008                   Enfield                120000
# 10  2008                 Greenwich                102000
# 11  2008                   Hackney                 97000
# 12  2008    Hammersmith and Fulham                 81000
# 13  2008                  Haringey                101000
# 14  2008                    Harrow                 85000
# ...

# %%
total_dwellings_2009 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,K", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2009.insert(0, 'Year', '2009')
total_dwellings_2009
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2009            City of London                  5000
# 1   2009      Barking and Dagenham                 71000
# 2   2009                    Barnet                138000
# 3   2009                    Bexley                 94000
# 4   2009                     Brent                110000
# 5   2009                   Bromley                134000
# 6   2009                    Camden                 99000
# 7   2009                   Croydon                146000
# 8   2009                    Ealing                126000
# 9   2009                   Enfield                121000
# 10  2009                 Greenwich                103000
# 11  2009                   Hackney                100000
# 12  2009    Hammersmith and Fulham                 81000
# 13  2009                  Haringey                102000
# 14  2009                    Harrow                 85000
# ...

# %%
total_dwellings_2010 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,L", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2010.insert(0, 'Year', '2010')
total_dwellings_2010
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2010            City of London                  5000
# 1   2010      Barking and Dagenham                 71000
# 2   2010                    Barnet                139000
# 3   2010                    Bexley                 95000
# 4   2010                     Brent                111000
# 5   2010                   Bromley                134000
# 6   2010                    Camden                 99000
# 7   2010                   Croydon                147000
# 8   2010                    Ealing                127000
# 9   2010                   Enfield                121000
# 10  2010                 Greenwich                103000
# 11  2010                   Hackney                102000
# 12  2010    Hammersmith and Fulham                 82000
# 13  2010                  Haringey                103000
# 14  2010                    Harrow                 86000
# ...

# %%
total_dwellings_2011 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,M", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2011.insert(0, 'Year', '2011')
total_dwellings_2011
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2011            City of London                  6000
# 1   2011      Barking and Dagenham                 71000
# 2   2011                    Barnet                139000
# 3   2011                    Bexley                 95000
# 4   2011                     Brent                112000
# 5   2011                   Bromley                135000
# 6   2011                    Camden                100000
# 7   2011                   Croydon                148000
# 8   2011                    Ealing                127000
# 9   2011                   Enfield                122000
# 10  2011                 Greenwich                103000
# 11  2011                   Hackney                102000
# 12  2011    Hammersmith and Fulham                 82000
# 13  2011                  Haringey                104000
# 14  2011                    Harrow                 87000
# ...

# %%
total_dwellings_2012 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,N", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2012.insert(0, 'Year', '2012')
total_dwellings_2012
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2012            City of London                  6000
# 1   2012      Barking and Dagenham                 71000
# 2   2012                    Barnet                141000
# 3   2012                    Bexley                 95000
# 4   2012                     Brent                113000
# 5   2012                   Bromley                136000
# 6   2012                    Camden                100000
# 7   2012                   Croydon                149000
# 8   2012                    Ealing                128000
# 9   2012                   Enfield                122000
# 10  2012                 Greenwich                105000
# 11  2012                   Hackney                104000
# 12  2012    Hammersmith and Fulham                 83000
# 13  2012                  Haringey                105000
# 14  2012                    Harrow                 87000
# ...

# %%
total_dwellings_2013 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,O", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2013.insert(0, 'Year', '2013')
total_dwellings_2013
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2013            City of London                  6000
# 1   2013      Barking and Dagenham                 72000
# 2   2013                    Barnet                143000
# 3   2013                    Bexley                 96000
# 4   2013                     Brent                113000
# 5   2013                   Bromley                136000
# 6   2013                    Camden                101000
# 7   2013                   Croydon                150000
# 8   2013                    Ealing                129000
# 9   2013                   Enfield                123000
# 10  2013                 Greenwich                105000
# 11  2013                   Hackney                104000
# 12  2013    Hammersmith and Fulham                 83000
# 13  2013                  Haringey                106000
# 14  2013                    Harrow                 88000
# ...

# %%
total_dwellings_2014 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,P", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2014.insert(0, 'Year', '2014')
total_dwellings_2014
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2014            City of London                  6000
# 1   2014      Barking and Dagenham                 73000
# 2   2014                    Barnet                144000
# 3   2014                    Bexley                 96000
# 4   2014                     Brent                114000
# 5   2014                   Bromley                136000
# 6   2014                    Camden                101000
# 7   2014                   Croydon                151000
# 8   2014                    Ealing                130000
# 9   2014                   Enfield                123000
# 10  2014                 Greenwich                106000
# 11  2014                   Hackney                105000
# 12  2014    Hammersmith and Fulham                 84000
# 13  2014                  Haringey                107000
# 14  2014                    Harrow                 88000
# ...

# %%
total_dwellings_2015 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,Q", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2015.insert(0, 'Year', '2015')
total_dwellings_2015
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2015            City of London                  6000
# 1   2015      Barking and Dagenham                 73000
# 2   2015                    Barnet                145000
# 3   2015                    Bexley                 97000
# 4   2015                     Brent                116000
# 5   2015                   Bromley                137000
# 6   2015                    Camden                102000
# 7   2015                   Croydon                153000
# 8   2015                    Ealing                131000
# 9   2015                   Enfield                124000
# 10  2015                 Greenwich                107000
# 11  2015                   Hackney                107000
# 12  2015    Hammersmith and Fulham                 85000
# 13  2015                  Haringey                107000
# 14  2015                    Harrow                 88000
# ...

# %%
total_dwellings_2016 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,R", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2016.insert(0, 'Year', '2016')
total_dwellings_2016
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2016            City of London                  6000
# 1   2016      Barking and Dagenham                 74000
# 2   2016                    Barnet                147000
# 3   2016                    Bexley                 97000
# 4   2016                     Brent                117000
# 5   2016                   Bromley                138000
# 6   2016                    Camden                103000
# 7   2016                   Croydon                155000
# 8   2016                    Ealing                131000
# 9   2016                   Enfield                124000
# 10  2016                 Greenwich                109000
# 11  2016                   Hackney                108000
# 12  2016    Hammersmith and Fulham                 86000
# 13  2016                  Haringey                107000
# 14  2016                    Harrow                 89000
# ...

# %%
total_dwellings_2017 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,S", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2017.insert(0, 'Year', '2017')
total_dwellings_2017
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2017            City of London                  6000
# 1   2017      Barking and Dagenham                 75000
# 2   2017                    Barnet                149000
# 3   2017                    Bexley                 98000
# 4   2017                     Brent                118000
# 5   2017                   Bromley                138000
# 6   2017                    Camden                104000
# 7   2017                   Croydon                157000
# 8   2017                    Ealing                132000
# 9   2017                   Enfield                125000
# 10  2017                 Greenwich                111000
# 11  2017                   Hackney                109000
# 12  2017    Hammersmith and Fulham                 87000
# 13  2017                  Haringey                108000
# 14  2017                    Harrow                 90000
# ...

# %%
total_dwellings_2018 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,T", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2018.insert(0, 'Year', '2018')
total_dwellings_2018
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2018            City of London                  6000
# 1   2018      Barking and Dagenham                 75000
# 2   2018                    Barnet                151000
# 3   2018                    Bexley                 98000
# 4   2018                     Brent                119000
# 5   2018                   Bromley                139000
# 6   2018                    Camden                105000
# 7   2018                   Croydon                159000
# 8   2018                    Ealing                134000
# 9   2018                   Enfield                126000
# 10  2018                 Greenwich                113000
# 11  2018                   Hackney                110000
# 12  2018    Hammersmith and Fulham                 88000
# 13  2018                  Haringey                109000
# 14  2018                    Harrow                 91000
# ...

# %%
total_dwellings_2019 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,U", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2019.insert(0, 'Year', '2019')
total_dwellings_2019
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2019            City of London                  7000
# 1   2019      Barking and Dagenham                 76000
# 2   2019                    Barnet                153000
# 3   2019                    Bexley                 98000
# 4   2019                     Brent                120000
# 5   2019                   Bromley                140000
# 6   2019                    Camden                106000
# 7   2019                   Croydon                161000
# 8   2019                    Ealing                135000
# 9   2019                   Enfield                126000
# 10  2019                 Greenwich                114000
# 11  2019                   Hackney                112000
# 12  2019    Hammersmith and Fulham                 89000
# 13  2019                  Haringey                109000
# 14  2019                    Harrow                 92000
# ...

# %%
total_dwellings_2020= pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,V", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2020.insert(0, 'Year', '2020')
total_dwellings_2020
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2020            City of London                  7000
# 1   2020      Barking and Dagenham                 77000
# 2   2020                    Barnet                155000
# 3   2020                    Bexley                 99000
# 4   2020                     Brent                123000
# 5   2020                   Bromley                140000
# 6   2020                    Camden                107000
# 7   2020                   Croydon                163000
# 8   2020                    Ealing                137000
# 9   2020                   Enfield                127000
# 10  2020                 Greenwich                117000
# 11  2020                   Hackney                112000
# 12  2020    Hammersmith and Fulham                 90000
# 13  2020                  Haringey                110000
# 14  2020                    Harrow                 93000
# ...

# %%
total_dwellings_2021 = pd.read_excel('../../Datasets/01_raw_data_files/net-additional-dwellings-total-stock-borough.xlsx', sheet_name='All dwellings (rounded)', skiprows=3, nrows=33, usecols="B,W", header=None, names=['Local Authority Districts', 'Total Dwelling Stock'])
total_dwellings_2021.insert(0, 'Year', '2021')
total_dwellings_2021
# Out:
#     Year Local Authority Districts  Total Dwelling Stock
# 0   2021            City of London                  7000
# 1   2021      Barking and Dagenham                 78000
# 2   2021                    Barnet                157000
# 3   2021                    Bexley                 99000
# 4   2021                     Brent                125000
# 5   2021                   Bromley                140000
# 6   2021                    Camden                107000
# 7   2021                   Croydon                165000
# 8   2021                    Ealing                139000
# 9   2021                   Enfield                127000
# 10  2021                 Greenwich                118000
# 11  2021                   Hackney                113000
# 12  2021    Hammersmith and Fulham                 92000
# 13  2021                  Haringey                112000
# 14  2021                    Harrow                 94000
# ...

# %% [markdown]
# Combining all years:

# %%
total_dwellings= pd.concat([total_dwellings_2006, total_dwellings_2007, total_dwellings_2008, total_dwellings_2009, total_dwellings_2010, total_dwellings_2011, total_dwellings_2012, total_dwellings_2013, total_dwellings_2014, total_dwellings_2015, total_dwellings_2016, total_dwellings_2017, total_dwellings_2018, total_dwellings_2019, total_dwellings_2020, total_dwellings_2021], ignore_index=True,axis=0)
total_dwellings
# Out:
#      Year Local Authority Districts  Total Dwelling Stock
# 0    2006            City of London                  5000
# 1    2006      Barking and Dagenham                 70000
# 2    2006                    Barnet                135000
# 3    2006                    Bexley                 93000
# 4    2006                     Brent                107000
# ..    ...                       ...                   ...
# 523  2021                    Sutton                 84000
# 524  2021             Tower Hamlets                129000
# 525  2021            Waltham Forest                106000
# 526  2021                Wandsworth                151000
# 527  2021               Westminster                127000
#
# [528 rows x 3 columns]

# %% [markdown]
# Combining by region:

# %%
district_categories = {
    'Camden': 'Inner London', 'Greenwich': 'Inner London', 'Hackney': 'Inner London', 'Hammersmith and Fulham': 'Inner London', 'Islington': 'Inner London',
    'Kensington and Chelsea': 'Inner London', 'Lambeth': 'Inner London', 'Lewisham': 'Inner London', 'Southwark': 'Inner London', 'Tower Hamlets': 'Inner London',
    'Wandsworth': 'Inner London', 'Westminster': 'Inner London', 'City of London': 'City of London',
    'Barking and Dagenham': 'Outer London', 'Barnet': 'Outer London', 'Bexley': 'Outer London', 'Brent': 'Outer London', 'Bromley': 'Outer London',
    'Croydon': 'Outer London', 'Ealing': 'Outer London', 'Enfield': 'Outer London', 'Haringey': 'Outer London', 'Harrow': 'Outer London',
    'Havering': 'Outer London', 'Hillingdon': 'Outer London', 'Hounslow': 'Outer London', 'Kingston upon Thames': 'Outer London', 'Merton': 'Outer London',
    'Newham': 'Outer London', 'Redbridge': 'Outer London', 'Richmond upon Thames': 'Outer London', 'Sutton': 'Outer London', 'Waltham Forest': 'Outer London'
}

# Add a new column for district categories
total_dwellings['Region'] = total_dwellings['Local Authority Districts'].map(district_categories)

# display updated DataFrame
total_dwellings.head(33)
# Out:
#     Year Local Authority Districts  Total Dwelling Stock          Region
# 0   2006            City of London                  5000  City of London
# 1   2006      Barking and Dagenham                 70000    Outer London
# 2   2006                    Barnet                135000    Outer London
# 3   2006                    Bexley                 93000    Outer London
# 4   2006                     Brent                107000    Outer London
# 5   2006                   Bromley                131000    Outer London
# 6   2006                    Camden                 96000    Inner London
# 7   2006                   Croydon                143000    Outer London
# 8   2006                    Ealing                123000    Outer London
# 9   2006                   Enfield                118000    Outer London
# 10  2006                 Greenwich                101000    Inner London
# 11  2006                   Hackney                 94000    Inner London
# ...

# %%
#checking if any values are null
total_dwellings.isnull().values.any()
# Out:
# False

# %%
#dropping districts column
total_dwellings.drop(columns=['Local Authority Districts'], inplace=True)

# %%
total_dwellings_by_region= total_dwellings.groupby(['Region', 'Year']).sum().reset_index()
total_dwellings_by_region
# Out:
#             Region  Year  Total Dwelling Stock
# 0   City of London  2006                  5000
# 1   City of London  2007                  5000
# 2   City of London  2008                  5000
# 3   City of London  2009                  5000
# 4   City of London  2010                  5000
# 5   City of London  2011                  6000
# 6   City of London  2012                  6000
# 7   City of London  2013                  6000
# 8   City of London  2014                  6000
# 9   City of London  2015                  6000
# 10  City of London  2016                  6000
# 11  City of London  2017                  6000
# 12  City of London  2018                  6000
# 13  City of London  2019                  7000
# 14  City of London  2020                  7000
# 15  City of London  2021                  7000
# 16    Inner London  2006               1224000
# 17    Inner London  2007               1241000
# 18    Inner London  2008               1255000
# ...

# %% [markdown]
# Saving cleaned and combined by Inner, Outer, City of London Region dataset to a new file:

# %%
total_dwellings_by_region.to_csv('../../Datasets/02_clean_data_files/total_dwellings_by_region.csv')
